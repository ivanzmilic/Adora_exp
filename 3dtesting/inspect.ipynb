# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
spec = np.load('/dat/milic/adora_synth/test.npz.npy')

# %%
spec.shape
# Out:
# (1536, 1536, 4, 201)

# %%
# Plot all the intensities:
for i in range(0,8):
    for j in range(0,8):
        plt.plot(spec[i,j,0])

# %%
I_qs = np.mean(spec[:,:,0,0], axis=(0,1))
plt.figure(figsize=(10,8.5))
plt.imshow(spec[:,:,0,50].T/I_qs, origin='lower', cmap='inferno', vmin=0.2,vmax=0.7)
