# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
# open spectra 
spectra = np.load('/dat/milic/synthesized_cube.npy')

# %%
spectra.shape
spectra /= np.mean(spectra[:,:,0,0])

# %%
# Do a quick 4x4 plot to show the structure:

plt.figure(figsize=(16,12))
plt.subplot(2,2,1)
plt.imshow(spectra[:, :, 0,0].T, cmap='gray',vmin=0.65,vmax=1.35)
plt.subplot(2,2,2)
plt.imshow(spectra[:, :, 0,50].T, cmap='gray',vmin=0.1,vmax=0.5)
plt.subplot(2,2,3)
plt.imshow(spectra[:, :, 3,45].T, cmap='PuOr',vmin=-0.05,vmax=0.05)
plt.subplot(2,2,4)
plt.plot(mean[0])
plt.savefig('adoratest.png')

# %%
mean = np.mean(spectra, axis=(0, 1))

# %%
plt.plot(mean[0])
